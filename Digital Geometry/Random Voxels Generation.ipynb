# %% [markdown]
# #### Random voxels generation by changing reference point to the next generated voxel

# %%
# %matplotlib notebook 
import matplotlib.pyplot as plt
import numpy as np
import random
from mpl_toolkits.mplot3d import Axes3D
N=100 #Number of voxels to be plotted
limit=40
x,y,z=int(limit/2),int(limit/2),int(limit/2)
#print(x,y,z)
k=[x,y,z]
store=[]
store.append(k)

c=0
while c<N:
    l=[]
    
    v0=[x+1,y,z]
    v1=[x,y+1,z]
    v2=[x,y,z+1]
    v3=[x-1,y,z]
    v4=[x,y-1,z]
    v5=[x,y,z-1]
    
    l.append(v0)
    l.append(v1)
    l.append(v2)
    l.append(v3)
    l.append(v4)
    l.append(v5)
    
    #print(l,"r")
    rand=random.choice(l)
    #print(rand)
    if rand not in store:
        store.append(rand)
        x=rand[0]
        y=rand[1]
        z=rand[2]
        c+=1
#File Handling and storing the dataset in .txt file
f=open('voxel_dataset.txt','w+')
for i in range(len(store)):
    f.write("%d " %store[i][0])
    f.write("%d " %store[i][1])
    f.write("%d " %store[i][2])
    f.write("\n")
f.truncate()

print(store)
#plotting the points
X,Y,Z=np.indices((limit,limit,limit))
vi=(X==store[0][0])&(Y==store[0][1])&(Z==store[0][2])
v=(X==x)&(Y==y)&(Z==z)
#print(x,y,z)
#print(v)
#print("k")
for i in range(len(store)):
    x1,y1,z1=store[i][0],store[i][1],store[i][2]
    v[x1,y1,z1]=True
#print(v)
vf=(X==x1)&(Y==y1)&(Z==z1)
ax = plt.figure().add_subplot(projection='3d')
ax.voxels(v, facecolors='red', edgecolor='black')
ax.voxels(vf, facecolors='blue', edgecolor='black')
ax.voxels(vi, facecolors='yellow', edgecolor='black')
ax.text(store[0][0],store[0][1],store[0][2],"Start Voxel",zdir='x',color='k')
ax.text(x1,y1,z1,"End Voxel",zdir='x',color='k')

#setting the limits
ax.set_xlim(0,limit)
ax.set_ylim(0,limit)
ax.set_zlim(0,limit)
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.set_zlabel("Z-axis")
ax.set_xlabel("X-axis")
ax.can_zoom()
ax.can_pan()
plt.savefig('voxel.pdf',dpi=300,bbox_inches='tight')
plt.show()
# Out:
# [[20, 20, 20], [20, 21, 20], [20, 22, 20], [20, 22, 19], [21, 22, 19], [22, 22, 19], [22, 22, 20], [21, 22, 20], [21, 22, 21], [21, 22, 22], [22, 22, 22], [22, 22, 21], [22, 23, 21], [22, 23, 20], [22, 23, 19], [23, 23, 19], [23, 23, 18], [22, 23, 18], [21, 23, 18], [21, 24, 18], [22, 24, 18], [22, 24, 17], [22, 25, 17], [21, 25, 17], [21, 25, 16], [20, 25, 16], [20, 25, 15], [20, 24, 15], [19, 24, 15], [19, 25, 15], [19, 26, 15], [19, 27, 15], [20, 27, 15], [20, 26, 15], [20, 26, 14], [20, 25, 14], [21, 25, 14], [22, 25, 14], [22, 26, 14], [21, 26, 14], [21, 26, 13], [21, 27, 13], [21, 27, 12], [22, 27, 12], [22, 26, 12], [22, 25, 12], [22, 25, 11], [22, 26, 11], [22, 27, 11], [21, 27, 11], [20, 27, 11], [20, 28, 11], [19, 28, 11], [19, 29, 11], [20, 29, 11], [21, 29, 11], [21, 28, 11], [21, 28, 10], [22, 28, 10], [22, 27, 10], [22, 27, 9], [22, 28, 9], [21, 28, 9], [21, 29, 9], [21, 29, 8], [21, 29, 7], [22, 29, 7], [22, 29, 8], [23, 29, 8], [24, 29, 8], [25, 29, 8], [25, 29, 7], [26, 29, 7], [26, 29, 6], [26, 28, 6], [27, 28, 6], [27, 28, 5], [27, 27, 5], [27, 26, 5], [26, 26, 5], [26, 27, 5], [26, 27, 4], [27, 27, 4], [27, 28, 4], [27, 28, 3], [28, 28, 3], [29, 28, 3], [29, 29, 3], [30, 29, 3], [30, 30, 3], [30, 30, 4], [30, 29, 4], [31, 29, 4], [31, 30, 4], [31, 30, 3], [31, 30, 2], [31, 31, 2], [31, 31, 1], [30, 31, 1], [30, 31, 2], [30, 31, 3]]
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### Random voxels generation by selcting random reference point from already generated voxels

# %%
# %matplotlib notebook 
import matplotlib.pyplot as plt
import numpy as np
import random
from mpl_toolkits.mplot3d import Axes3D
N=200 #Number of voxels to be plotted
limit=40
x,y,z=int(limit/2),int(limit/2),int(limit/2)
#print(x,y,z)
k=[x,y,z]
store=[]
store.append(k)
c=0
while c<N:
    l=[]
    
    #choosing Random voxel
    rand_ref=random.choice(store)
    x=rand_ref[0]
    y=rand_ref[1]
    z=rand_ref[2]
    
    v0=[x+1,y,z]
    v1=[x,y+1,z]
    v2=[x,y,z+1]
    v3=[x-1,y,z]
    v4=[x,y-1,z]
    v5=[x,y,z-1]
    
    l.append(v0)
    l.append(v1)
    l.append(v2)
    l.append(v3)
    l.append(v4)
    l.append(v5)
    
    #print(l,"r")
    #Choosing random face of Chosen voxel
    rand=random.choice(l)
    
    #print(rand)
    if rand not in store:
        store.append(rand)
        x=rand[0]
        y=rand[1]
        z=rand[2]
        c+=1
#File Handling and storing the dataset in .txt file
f=open('voxel_dataset.txt','w+')
for i in range(len(store)):
    f.write("%d " %store[i][0])
    f.write("%d " %store[i][1])
    f.write("%d " %store[i][2])
    f.write("\n")
f.truncate()

print(store)

#plotting the points
X,Y,Z=np.indices((limit,limit,limit))
vi=(X==store[0][0])&(Y==store[0][1])&(Z==store[0][2])
v=(X==x)&(Y==y)&(Z==z)
#print(x,y,z)
#print(v)
#print("k")
for i in range(len(store)):
    x1,y1,z1=store[i][0],store[i][1],store[i][2]
    v[x1,y1,z1]=True
#print(v)
vf=(X==x1)&(Y==y1)&(Z==z1)
ax = plt.figure().add_subplot(projection='3d')
ax.voxels(v, facecolors='red', edgecolor='black')
ax.voxels(vf, facecolors='blue', edgecolor='black')
ax.voxels(vi, facecolors='yellow', edgecolor='black')
ax.text(store[0][0],store[0][1],store[0][2],"Start Voxel",zdir='x',color='k')
ax.text(x1,y1,z1,"End Voxel",zdir='x',color='k')

#setting the limits
ax.set_xlim(0,limit)
ax.set_ylim(0,limit)
ax.set_zlim(0,limit)
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.set_zlabel("Z-axis")
ax.set_xlabel("X-axis")
ax.can_zoom()
ax.can_pan()
plt.savefig('voxel.pdf',dpi=300,bbox_inches='tight')
plt.show()
# Out:
# [[20, 20, 20], [19, 20, 20], [20, 20, 19], [19, 20, 19], [20, 21, 19], [19, 20, 21], [19, 21, 19], [21, 21, 19], [20, 21, 20], [19, 19, 20], [20, 19, 20], [18, 20, 19], [19, 19, 21], [21, 21, 18], [19, 19, 19], [20, 18, 20], [19, 20, 22], [20, 18, 19], [17, 20, 19], [16, 20, 19], [18, 19, 20], [17, 19, 20], [19, 18, 19], [20, 19, 19], [17, 21, 19], [16, 20, 20], [20, 20, 21], [18, 20, 22], [18, 18, 20